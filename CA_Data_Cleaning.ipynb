# %% [markdown]
# ## California COMStock Data Cleaning ##
#
# Seperately, but related to the overall California AC to Heat Pump work is an effort to clean, merge, and summarize the Commercial Building Stock (COMStock) data in order to provide helpful insights for our data analysis down the road. This workbook export product is
